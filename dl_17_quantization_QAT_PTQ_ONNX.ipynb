# %% [markdown]
# <a href="https://colab.research.google.com/github/Ibrah-N/Deep-Learning-Projects-Computer-Vision/blob/main/dl_17_quantization_QAT_PTQ_ONNX.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np
import time
import matplotlib.pyplot as plt


import tensorflow as tf

# %%
# Extract Saved dataset
# !unzip -q gdrive/MyDrive/human-emotions-datasethes.zip -d dataset/

# %%
# Configurations

TRAIN_DIR = '/content/dataset/Emotions Dataset/Emotions Dataset/train/'
VAL_DIR = '/content/dataset/Emotions Dataset/Emotions Dataset/test/'


CONFIG = {
    'IM_SIZE' : 256,
    'BATCH_SIZE' : 32,
    'N_CLASSES': 3,
    'LABELS' : ['angry', 'happy', 'sad'],
    'EPOCHS' : 6,
    'SEED' : 42,
    'FILTER_SIZE': 16,
    'POOL_SIZE': 2,
    'PATCH_SIZE' : 16,
    'KERNEL_SIZE': 3,
    'DROPOUT_RATE': 0.0,
    'LEARNING_RATE': 0.0001,
    'DENSE_1': 32,
    'DENSE_2': 16,
    }

# %%
# create tensorflow dataset

train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    TRAIN_DIR,
    labels='inferred',
    label_mode='categorical',
    class_names=CONFIG['LABELS'],
    batch_size=None,
    image_size=(CONFIG['IM_SIZE'], CONFIG['IM_SIZE']),
    seed=CONFIG['SEED'],
)


validation_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    VAL_DIR,
    labels='inferred',
    label_mode='categorical',
    class_names=CONFIG['LABELS'],
    batch_size=None,
    image_size=(CONFIG['IM_SIZE'], CONFIG['IM_SIZE']),
    seed=CONFIG['SEED'],
)
# Out:
# Found 6799 files belonging to 3 classes.
# Found 2278 files belonging to 3 classes.

# %%
# rescalling data

def resize_rescale(image, label):
    image  = tf.image.resize(image, (CONFIG['IM_SIZE'], CONFIG['IM_SIZE']))
    image = tf.cast(image/255. , tf.float32)
    return image, label

# %%
# train dataset prefetch

train_dataset = (
    train_dataset
    # .map(resize_rescale)
    .shuffle(buffer_size=1000, reshuffle_each_iteration=True)
    .batch(CONFIG['BATCH_SIZE'])
    .prefetch(buffer_size=tf.data.AUTOTUNE)
)

# %%
# validation dataset prefetch
validation_dataset = (
    validation_dataset
    # .map(resize_rescale)
    .shuffle(buffer_size=1000, reshuffle_each_iteration=True)
    .batch(CONFIG['BATCH_SIZE'])
    .prefetch(buffer_size=tf.data.AUTOTUNE)
)

# %%
batch_data= validation_dataset.take(1)
img = next(iter(batch_data))[0][0]
lbl = next(iter(batch_data))[1][0]

# %% [markdown]
# ## Quantization

# %% [markdown]
# ### Post Training Quantization

# %%
# !pip install -q TFlite
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.6/123.6 kB 1.2 MB/s eta 0:00:00

# %%
# simple conversion

convert_model = tf.lite.TFLiteConverter.from_keras_model(model)
convert_model = convert_model.convert()

# %%
# conversion with optimization

# data generator
def data_gen():
  for x, y in train_dataset.take(1):
    yield [x], [y]


# conversion parameters
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.inference_input_type = tf.uint8
converter.interence_output_type = tf.uint8
converter.representative_dataset = data_gen


# convert and save the model
tflite_model = converter.convert()
tflite_model = open("model.tflite", "wb").write(tflite_model)
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow/lite/python/convert.py:953: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(

# %%
# install tflite run time
# !pip install -q tflite_runtime
import tflite_runtime as tflite

# %%
# inference on tflite model
interpreter = tflite.Interpreter(model_path="model.tflite")
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()[0]
output_details = interpreter.get_output_details()[0]

test_image = np.expand_dims(img, axis=0).astype(input_detail['dtype'])
interpreter.set_tensor(input_details['index'], test_image)

interpreter.invoke()
interpreter.get_tensor(output_details['index'])[0]

# %% [markdown]
# ### Quantization Aware Training

# %%
# !pip install -q -U tensorflow-model-optimization
import tensorflow_model_optimization as tfmot

# %%
# download a pretrained efficient net B4

effnet_b4 = tf.keras.applications.EfficientNetB4(
    weights='imagenet',
    include_top=False,
    input_shape=(CONFIG['IM_SIZE'], CONFIG['IM_SIZE'], 3)
)

# %%
effnet_b4.trainable = False

# %%
x = effnet_b4.output
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dense(CONFIG['DENSE_1'], activation='relu')(x)
x = tf.keras.layers.Dense(CONFIG['N_CLASSES'], activation='softmax')(x)
model = tf.keras.Model(inputs=effnet_b4.input, outputs=x)
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  rescaling_2 (Rescaling)     (None, 256, 256, 3)          0         ['input_2[0][0]']
#
#  normalization_1 (Normaliza  (None, 256, 256, 3)          7         ['rescaling_2[0][0]']
#  tion)
#
#  rescaling_3 (Rescaling)     (None, 256, 256, 3)          0         ['normalization_1[0][0]']
#
#  stem_conv_pad (ZeroPadding  (None, 257, 257, 3)          0         ['rescaling_3[0][0]']
#  2D)
#
#  stem_conv (Conv2D)          (None, 128, 128, 48)         1296      ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 128, 128, 48)         192       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 128, 128, 48)         0         ['stem_bn[0][0]']
#  n)
#
#  block1a_dwconv (DepthwiseC  (None, 128, 128, 48)         432       ['stem_activation[0][0]']
#  onv2D)
#
#  block1a_bn (BatchNormaliza  (None, 128, 128, 48)         192       ['block1a_dwconv[0][0]']
#  tion)
#
#  block1a_activation (Activa  (None, 128, 128, 48)         0         ['block1a_bn[0][0]']
#  tion)
#
#  block1a_se_squeeze (Global  (None, 48)                   0         ['block1a_activation[0][0]']
#  AveragePooling2D)
#
#  block1a_se_reshape (Reshap  (None, 1, 1, 48)             0         ['block1a_se_squeeze[0][0]']
#  e)
#
#  block1a_se_reduce (Conv2D)  (None, 1, 1, 12)             588       ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)  (None, 1, 1, 48)             624       ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multipl  (None, 128, 128, 48)         0         ['block1a_activation[0][0]',
#  y)                                                                  'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv  (None, 128, 128, 24)         1152      ['block1a_se_excite[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 128, 128, 24)         96        ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block1b_dwconv (DepthwiseC  (None, 128, 128, 24)         216       ['block1a_project_bn[0][0]']
#  onv2D)
#
#  block1b_bn (BatchNormaliza  (None, 128, 128, 24)         96        ['block1b_dwconv[0][0]']
#  tion)
#
#  block1b_activation (Activa  (None, 128, 128, 24)         0         ['block1b_bn[0][0]']
#  tion)
#
#  block1b_se_squeeze (Global  (None, 24)                   0         ['block1b_activation[0][0]']
#  AveragePooling2D)
#
#  block1b_se_reshape (Reshap  (None, 1, 1, 24)             0         ['block1b_se_squeeze[0][0]']
#  e)
#
#  block1b_se_reduce (Conv2D)  (None, 1, 1, 6)              150       ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)  (None, 1, 1, 24)             168       ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multipl  (None, 128, 128, 24)         0         ['block1b_activation[0][0]',
#  y)                                                                  'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv  (None, 128, 128, 24)         576       ['block1b_se_excite[0][0]']
#  2D)
#
#  block1b_project_bn (BatchN  (None, 128, 128, 24)         96        ['block1b_project_conv[0][0]']
#  ormalization)
#
#  block1b_drop (Dropout)      (None, 128, 128, 24)         0         ['block1b_project_bn[0][0]']
#
#  block1b_add (Add)           (None, 128, 128, 24)         0         ['block1b_drop[0][0]',
#                                                                      'block1a_project_bn[0][0]']
#
#  block2a_expand_conv (Conv2  (None, 128, 128, 144)        3456      ['block1b_add[0][0]']
#  D)
#
#  block2a_expand_bn (BatchNo  (None, 128, 128, 144)        576       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 128, 128, 144)        0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_dwconv_pad (ZeroPa  (None, 129, 129, 144)        0         ['block2a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block2a_dwconv (DepthwiseC  (None, 64, 64, 144)          1296      ['block2a_dwconv_pad[0][0]']
#  onv2D)
#
#  block2a_bn (BatchNormaliza  (None, 64, 64, 144)          576       ['block2a_dwconv[0][0]']
#  tion)
#
#  block2a_activation (Activa  (None, 64, 64, 144)          0         ['block2a_bn[0][0]']
#  tion)
#
#  block2a_se_squeeze (Global  (None, 144)                  0         ['block2a_activation[0][0]']
#  AveragePooling2D)
#
#  block2a_se_reshape (Reshap  (None, 1, 1, 144)            0         ['block2a_se_squeeze[0][0]']
#  e)
#
#  block2a_se_reduce (Conv2D)  (None, 1, 1, 6)              870       ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)  (None, 1, 1, 144)            1008      ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multipl  (None, 64, 64, 144)          0         ['block2a_activation[0][0]',
#  y)                                                                  'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv  (None, 64, 64, 32)           4608      ['block2a_se_excite[0][0]']
#  2D)
#
#  block2a_project_bn (BatchN  (None, 64, 64, 32)           128       ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 64, 64, 192)          6144      ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 64, 64, 192)          768       ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 64, 64, 192)          0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_dwconv (DepthwiseC  (None, 64, 64, 192)          1728      ['block2b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2b_bn (BatchNormaliza  (None, 64, 64, 192)          768       ['block2b_dwconv[0][0]']
#  tion)
#
#  block2b_activation (Activa  (None, 64, 64, 192)          0         ['block2b_bn[0][0]']
#  tion)
#
#  block2b_se_squeeze (Global  (None, 192)                  0         ['block2b_activation[0][0]']
#  AveragePooling2D)
#
#  block2b_se_reshape (Reshap  (None, 1, 1, 192)            0         ['block2b_se_squeeze[0][0]']
#  e)
#
#  block2b_se_reduce (Conv2D)  (None, 1, 1, 8)              1544      ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)  (None, 1, 1, 192)            1728      ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multipl  (None, 64, 64, 192)          0         ['block2b_activation[0][0]',
#  y)                                                                  'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv  (None, 64, 64, 32)           6144      ['block2b_se_excite[0][0]']
#  2D)
#
#  block2b_project_bn (BatchN  (None, 64, 64, 32)           128       ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (Dropout)      (None, 64, 64, 32)           0         ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)           (None, 64, 64, 32)           0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2  (None, 64, 64, 192)          6144      ['block2b_add[0][0]']
#  D)
#
#  block2c_expand_bn (BatchNo  (None, 64, 64, 192)          768       ['block2c_expand_conv[0][0]']
#  rmalization)
#
#  block2c_expand_activation   (None, 64, 64, 192)          0         ['block2c_expand_bn[0][0]']
#  (Activation)
#
#  block2c_dwconv (DepthwiseC  (None, 64, 64, 192)          1728      ['block2c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2c_bn (BatchNormaliza  (None, 64, 64, 192)          768       ['block2c_dwconv[0][0]']
#  tion)
#
#  block2c_activation (Activa  (None, 64, 64, 192)          0         ['block2c_bn[0][0]']
#  tion)
#
#  block2c_se_squeeze (Global  (None, 192)                  0         ['block2c_activation[0][0]']
#  AveragePooling2D)
#
#  block2c_se_reshape (Reshap  (None, 1, 1, 192)            0         ['block2c_se_squeeze[0][0]']
#  e)
#
#  block2c_se_reduce (Conv2D)  (None, 1, 1, 8)              1544      ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)  (None, 1, 1, 192)            1728      ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multipl  (None, 64, 64, 192)          0         ['block2c_activation[0][0]',
#  y)                                                                  'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv  (None, 64, 64, 32)           6144      ['block2c_se_excite[0][0]']
#  2D)
#
#  block2c_project_bn (BatchN  (None, 64, 64, 32)           128       ['block2c_project_conv[0][0]']
#  ormalization)
#
#  block2c_drop (Dropout)      (None, 64, 64, 32)           0         ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)           (None, 64, 64, 32)           0         ['block2c_drop[0][0]',
#                                                                      'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2  (None, 64, 64, 192)          6144      ['block2c_add[0][0]']
#  D)
#
#  block2d_expand_bn (BatchNo  (None, 64, 64, 192)          768       ['block2d_expand_conv[0][0]']
#  rmalization)
#
#  block2d_expand_activation   (None, 64, 64, 192)          0         ['block2d_expand_bn[0][0]']
#  (Activation)
#
#  block2d_dwconv (DepthwiseC  (None, 64, 64, 192)          1728      ['block2d_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2d_bn (BatchNormaliza  (None, 64, 64, 192)          768       ['block2d_dwconv[0][0]']
#  tion)
#
#  block2d_activation (Activa  (None, 64, 64, 192)          0         ['block2d_bn[0][0]']
#  tion)
#
#  block2d_se_squeeze (Global  (None, 192)                  0         ['block2d_activation[0][0]']
#  AveragePooling2D)
#
#  block2d_se_reshape (Reshap  (None, 1, 1, 192)            0         ['block2d_se_squeeze[0][0]']
#  e)
#
#  block2d_se_reduce (Conv2D)  (None, 1, 1, 8)              1544      ['block2d_se_reshape[0][0]']
#
#  block2d_se_expand (Conv2D)  (None, 1, 1, 192)            1728      ['block2d_se_reduce[0][0]']
#
#  block2d_se_excite (Multipl  (None, 64, 64, 192)          0         ['block2d_activation[0][0]',
#  y)                                                                  'block2d_se_expand[0][0]']
#
#  block2d_project_conv (Conv  (None, 64, 64, 32)           6144      ['block2d_se_excite[0][0]']
#  2D)
#
#  block2d_project_bn (BatchN  (None, 64, 64, 32)           128       ['block2d_project_conv[0][0]']
#  ormalization)
#
#  block2d_drop (Dropout)      (None, 64, 64, 32)           0         ['block2d_project_bn[0][0]']
#
#  block2d_add (Add)           (None, 64, 64, 32)           0         ['block2d_drop[0][0]',
#                                                                      'block2c_add[0][0]']
#
#  block3a_expand_conv (Conv2  (None, 64, 64, 192)          6144      ['block2d_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 64, 64, 192)          768       ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 64, 64, 192)          0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_dwconv_pad (ZeroPa  (None, 67, 67, 192)          0         ['block3a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block3a_dwconv (DepthwiseC  (None, 32, 32, 192)          4800      ['block3a_dwconv_pad[0][0]']
#  onv2D)
#
#  block3a_bn (BatchNormaliza  (None, 32, 32, 192)          768       ['block3a_dwconv[0][0]']
#  tion)
#
#  block3a_activation (Activa  (None, 32, 32, 192)          0         ['block3a_bn[0][0]']
#  tion)
#
#  block3a_se_squeeze (Global  (None, 192)                  0         ['block3a_activation[0][0]']
#  AveragePooling2D)
#
#  block3a_se_reshape (Reshap  (None, 1, 1, 192)            0         ['block3a_se_squeeze[0][0]']
#  e)
#
#  block3a_se_reduce (Conv2D)  (None, 1, 1, 8)              1544      ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)  (None, 1, 1, 192)            1728      ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multipl  (None, 32, 32, 192)          0         ['block3a_activation[0][0]',
#  y)                                                                  'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv  (None, 32, 32, 56)           10752     ['block3a_se_excite[0][0]']
#  2D)
#
#  block3a_project_bn (BatchN  (None, 32, 32, 56)           224       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  block3b_expand_conv (Conv2  (None, 32, 32, 336)          18816     ['block3a_project_bn[0][0]']
#  D)
#
#  block3b_expand_bn (BatchNo  (None, 32, 32, 336)          1344      ['block3b_expand_conv[0][0]']
#  rmalization)
#
#  block3b_expand_activation   (None, 32, 32, 336)          0         ['block3b_expand_bn[0][0]']
#  (Activation)
#
#  block3b_dwconv (DepthwiseC  (None, 32, 32, 336)          8400      ['block3b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block3b_bn (BatchNormaliza  (None, 32, 32, 336)          1344      ['block3b_dwconv[0][0]']
#  tion)
#
#  block3b_activation (Activa  (None, 32, 32, 336)          0         ['block3b_bn[0][0]']
#  tion)
#
#  block3b_se_squeeze (Global  (None, 336)                  0         ['block3b_activation[0][0]']
#  AveragePooling2D)
#
#  block3b_se_reshape (Reshap  (None, 1, 1, 336)            0         ['block3b_se_squeeze[0][0]']
#  e)
#
#  block3b_se_reduce (Conv2D)  (None, 1, 1, 14)             4718      ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)  (None, 1, 1, 336)            5040      ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multipl  (None, 32, 32, 336)          0         ['block3b_activation[0][0]',
#  y)                                                                  'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv  (None, 32, 32, 56)           18816     ['block3b_se_excite[0][0]']
#  2D)
#
#  block3b_project_bn (BatchN  (None, 32, 32, 56)           224       ['block3b_project_conv[0][0]']
#  ormalization)
#
#  block3b_drop (Dropout)      (None, 32, 32, 56)           0         ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)           (None, 32, 32, 56)           0         ['block3b_drop[0][0]',
#                                                                      'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2  (None, 32, 32, 336)          18816     ['block3b_add[0][0]']
#  D)
#
#  block3c_expand_bn (BatchNo  (None, 32, 32, 336)          1344      ['block3c_expand_conv[0][0]']
#  rmalization)
#
#  block3c_expand_activation   (None, 32, 32, 336)          0         ['block3c_expand_bn[0][0]']
#  (Activation)
#
#  block3c_dwconv (DepthwiseC  (None, 32, 32, 336)          8400      ['block3c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block3c_bn (BatchNormaliza  (None, 32, 32, 336)          1344      ['block3c_dwconv[0][0]']
#  tion)
#
#  block3c_activation (Activa  (None, 32, 32, 336)          0         ['block3c_bn[0][0]']
#  tion)
#
#  block3c_se_squeeze (Global  (None, 336)                  0         ['block3c_activation[0][0]']
#  AveragePooling2D)
#
#  block3c_se_reshape (Reshap  (None, 1, 1, 336)            0         ['block3c_se_squeeze[0][0]']
#  e)
#
#  block3c_se_reduce (Conv2D)  (None, 1, 1, 14)             4718      ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)  (None, 1, 1, 336)            5040      ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multipl  (None, 32, 32, 336)          0         ['block3c_activation[0][0]',
#  y)                                                                  'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv  (None, 32, 32, 56)           18816     ['block3c_se_excite[0][0]']
#  2D)
#
#  block3c_project_bn (BatchN  (None, 32, 32, 56)           224       ['block3c_project_conv[0][0]']
#  ormalization)
#
#  block3c_drop (Dropout)      (None, 32, 32, 56)           0         ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)           (None, 32, 32, 56)           0         ['block3c_drop[0][0]',
#                                                                      'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2  (None, 32, 32, 336)          18816     ['block3c_add[0][0]']
#  D)
#
#  block3d_expand_bn (BatchNo  (None, 32, 32, 336)          1344      ['block3d_expand_conv[0][0]']
#  rmalization)
#
#  block3d_expand_activation   (None, 32, 32, 336)          0         ['block3d_expand_bn[0][0]']
#  (Activation)
#
#  block3d_dwconv (DepthwiseC  (None, 32, 32, 336)          8400      ['block3d_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block3d_bn (BatchNormaliza  (None, 32, 32, 336)          1344      ['block3d_dwconv[0][0]']
#  tion)
#
#  block3d_activation (Activa  (None, 32, 32, 336)          0         ['block3d_bn[0][0]']
#  tion)
#
#  block3d_se_squeeze (Global  (None, 336)                  0         ['block3d_activation[0][0]']
#  AveragePooling2D)
#
#  block3d_se_reshape (Reshap  (None, 1, 1, 336)            0         ['block3d_se_squeeze[0][0]']
#  e)
#
#  block3d_se_reduce (Conv2D)  (None, 1, 1, 14)             4718      ['block3d_se_reshape[0][0]']
#
#  block3d_se_expand (Conv2D)  (None, 1, 1, 336)            5040      ['block3d_se_reduce[0][0]']
#
#  block3d_se_excite (Multipl  (None, 32, 32, 336)          0         ['block3d_activation[0][0]',
#  y)                                                                  'block3d_se_expand[0][0]']
#
#  block3d_project_conv (Conv  (None, 32, 32, 56)           18816     ['block3d_se_excite[0][0]']
#  2D)
#
#  block3d_project_bn (BatchN  (None, 32, 32, 56)           224       ['block3d_project_conv[0][0]']
#  ormalization)
#
#  block3d_drop (Dropout)      (None, 32, 32, 56)           0         ['block3d_project_bn[0][0]']
#
#  block3d_add (Add)           (None, 32, 32, 56)           0         ['block3d_drop[0][0]',
#                                                                      'block3c_add[0][0]']
#
#  block4a_expand_conv (Conv2  (None, 32, 32, 336)          18816     ['block3d_add[0][0]']
#  D)
#
#  block4a_expand_bn (BatchNo  (None, 32, 32, 336)          1344      ['block4a_expand_conv[0][0]']
#  rmalization)
#
#  block4a_expand_activation   (None, 32, 32, 336)          0         ['block4a_expand_bn[0][0]']
#  (Activation)
#
#  block4a_dwconv_pad (ZeroPa  (None, 33, 33, 336)          0         ['block4a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block4a_dwconv (DepthwiseC  (None, 16, 16, 336)          3024      ['block4a_dwconv_pad[0][0]']
#  onv2D)
#
#  block4a_bn (BatchNormaliza  (None, 16, 16, 336)          1344      ['block4a_dwconv[0][0]']
#  tion)
#
#  block4a_activation (Activa  (None, 16, 16, 336)          0         ['block4a_bn[0][0]']
#  tion)
#
#  block4a_se_squeeze (Global  (None, 336)                  0         ['block4a_activation[0][0]']
#  AveragePooling2D)
#
#  block4a_se_reshape (Reshap  (None, 1, 1, 336)            0         ['block4a_se_squeeze[0][0]']
#  e)
#
#  block4a_se_reduce (Conv2D)  (None, 1, 1, 14)             4718      ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)  (None, 1, 1, 336)            5040      ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multipl  (None, 16, 16, 336)          0         ['block4a_activation[0][0]',
#  y)                                                                  'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv  (None, 16, 16, 112)          37632     ['block4a_se_excite[0][0]']
#  2D)
#
#  block4a_project_bn (BatchN  (None, 16, 16, 112)          448       ['block4a_project_conv[0][0]']
#  ormalization)
#
#  block4b_expand_conv (Conv2  (None, 16, 16, 672)          75264     ['block4a_project_bn[0][0]']
#  D)
#
#  block4b_expand_bn (BatchNo  (None, 16, 16, 672)          2688      ['block4b_expand_conv[0][0]']
#  rmalization)
#
#  block4b_expand_activation   (None, 16, 16, 672)          0         ['block4b_expand_bn[0][0]']
#  (Activation)
#
#  block4b_dwconv (DepthwiseC  (None, 16, 16, 672)          6048      ['block4b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block4b_bn (BatchNormaliza  (None, 16, 16, 672)          2688      ['block4b_dwconv[0][0]']
#  tion)
#
#  block4b_activation (Activa  (None, 16, 16, 672)          0         ['block4b_bn[0][0]']
#  tion)
#
#  block4b_se_squeeze (Global  (None, 672)                  0         ['block4b_activation[0][0]']
#  AveragePooling2D)
#
#  block4b_se_reshape (Reshap  (None, 1, 1, 672)            0         ['block4b_se_squeeze[0][0]']
#  e)
#
#  block4b_se_reduce (Conv2D)  (None, 1, 1, 28)             18844     ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)  (None, 1, 1, 672)            19488     ['block4b_se_reduce[0][0]']
#
# ...
#  block6g_se_reshape (Reshap  (None, 1, 1, 1632)           0         ['block6g_se_squeeze[0][0]']
#  e)
#
#  block6g_se_reduce (Conv2D)  (None, 1, 1, 68)             111044    ['block6g_se_reshape[0][0]']
#
#  block6g_se_expand (Conv2D)  (None, 1, 1, 1632)           112608    ['block6g_se_reduce[0][0]']
#
#  block6g_se_excite (Multipl  (None, 8, 8, 1632)           0         ['block6g_activation[0][0]',
#  y)                                                                  'block6g_se_expand[0][0]']
#
#  block6g_project_conv (Conv  (None, 8, 8, 272)            443904    ['block6g_se_excite[0][0]']
#  2D)
#
#  block6g_project_bn (BatchN  (None, 8, 8, 272)            1088      ['block6g_project_conv[0][0]']
#  ormalization)
#
#  block6g_drop (Dropout)      (None, 8, 8, 272)            0         ['block6g_project_bn[0][0]']
#
#  block6g_add (Add)           (None, 8, 8, 272)            0         ['block6g_drop[0][0]',
#                                                                      'block6f_add[0][0]']
#
#  block6h_expand_conv (Conv2  (None, 8, 8, 1632)           443904    ['block6g_add[0][0]']
#  D)
#
#  block6h_expand_bn (BatchNo  (None, 8, 8, 1632)           6528      ['block6h_expand_conv[0][0]']
#  rmalization)
#
#  block6h_expand_activation   (None, 8, 8, 1632)           0         ['block6h_expand_bn[0][0]']
#  (Activation)
#
#  block6h_dwconv (DepthwiseC  (None, 8, 8, 1632)           40800     ['block6h_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block6h_bn (BatchNormaliza  (None, 8, 8, 1632)           6528      ['block6h_dwconv[0][0]']
#  tion)
#
#  block6h_activation (Activa  (None, 8, 8, 1632)           0         ['block6h_bn[0][0]']
#  tion)
#
#  block6h_se_squeeze (Global  (None, 1632)                 0         ['block6h_activation[0][0]']
#  AveragePooling2D)
#
#  block6h_se_reshape (Reshap  (None, 1, 1, 1632)           0         ['block6h_se_squeeze[0][0]']
#  e)
#
#  block6h_se_reduce (Conv2D)  (None, 1, 1, 68)             111044    ['block6h_se_reshape[0][0]']
#
#  block6h_se_expand (Conv2D)  (None, 1, 1, 1632)           112608    ['block6h_se_reduce[0][0]']
#
#  block6h_se_excite (Multipl  (None, 8, 8, 1632)           0         ['block6h_activation[0][0]',
#  y)                                                                  'block6h_se_expand[0][0]']
#
#  block6h_project_conv (Conv  (None, 8, 8, 272)            443904    ['block6h_se_excite[0][0]']
#  2D)
#
#  block6h_project_bn (BatchN  (None, 8, 8, 272)            1088      ['block6h_project_conv[0][0]']
#  ormalization)
#
#  block6h_drop (Dropout)      (None, 8, 8, 272)            0         ['block6h_project_bn[0][0]']
#
#  block6h_add (Add)           (None, 8, 8, 272)            0         ['block6h_drop[0][0]',
#                                                                      'block6g_add[0][0]']
#
#  block7a_expand_conv (Conv2  (None, 8, 8, 1632)           443904    ['block6h_add[0][0]']
#  D)
#
#  block7a_expand_bn (BatchNo  (None, 8, 8, 1632)           6528      ['block7a_expand_conv[0][0]']
#  rmalization)
#
#  block7a_expand_activation   (None, 8, 8, 1632)           0         ['block7a_expand_bn[0][0]']
#  (Activation)
#
#  block7a_dwconv (DepthwiseC  (None, 8, 8, 1632)           14688     ['block7a_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7a_bn (BatchNormaliza  (None, 8, 8, 1632)           6528      ['block7a_dwconv[0][0]']
#  tion)
#
#  block7a_activation (Activa  (None, 8, 8, 1632)           0         ['block7a_bn[0][0]']
#  tion)
#
#  block7a_se_squeeze (Global  (None, 1632)                 0         ['block7a_activation[0][0]']
#  AveragePooling2D)
#
#  block7a_se_reshape (Reshap  (None, 1, 1, 1632)           0         ['block7a_se_squeeze[0][0]']
#  e)
#
#  block7a_se_reduce (Conv2D)  (None, 1, 1, 68)             111044    ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)  (None, 1, 1, 1632)           112608    ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multipl  (None, 8, 8, 1632)           0         ['block7a_activation[0][0]',
#  y)                                                                  'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv  (None, 8, 8, 448)            731136    ['block7a_se_excite[0][0]']
#  2D)
#
#  block7a_project_bn (BatchN  (None, 8, 8, 448)            1792      ['block7a_project_conv[0][0]']
#  ormalization)
#
#  block7b_expand_conv (Conv2  (None, 8, 8, 2688)           1204224   ['block7a_project_bn[0][0]']
#  D)
#
#  block7b_expand_bn (BatchNo  (None, 8, 8, 2688)           10752     ['block7b_expand_conv[0][0]']
#  rmalization)
#
#  block7b_expand_activation   (None, 8, 8, 2688)           0         ['block7b_expand_bn[0][0]']
#  (Activation)
#
#  block7b_dwconv (DepthwiseC  (None, 8, 8, 2688)           24192     ['block7b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7b_bn (BatchNormaliza  (None, 8, 8, 2688)           10752     ['block7b_dwconv[0][0]']
#  tion)
#
#  block7b_activation (Activa  (None, 8, 8, 2688)           0         ['block7b_bn[0][0]']
#  tion)
#
#  block7b_se_squeeze (Global  (None, 2688)                 0         ['block7b_activation[0][0]']
#  AveragePooling2D)
#
#  block7b_se_reshape (Reshap  (None, 1, 1, 2688)           0         ['block7b_se_squeeze[0][0]']
#  e)
#
#  block7b_se_reduce (Conv2D)  (None, 1, 1, 112)            301168    ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)  (None, 1, 1, 2688)           303744    ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multipl  (None, 8, 8, 2688)           0         ['block7b_activation[0][0]',
#  y)                                                                  'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv  (None, 8, 8, 448)            1204224   ['block7b_se_excite[0][0]']
#  2D)
#
#  block7b_project_bn (BatchN  (None, 8, 8, 448)            1792      ['block7b_project_conv[0][0]']
#  ormalization)
#
#  block7b_drop (Dropout)      (None, 8, 8, 448)            0         ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)           (None, 8, 8, 448)            0         ['block7b_drop[0][0]',
#                                                                      'block7a_project_bn[0][0]']
#
#  top_conv (Conv2D)           (None, 8, 8, 1792)           802816    ['block7b_add[0][0]']
#
#  top_bn (BatchNormalization  (None, 8, 8, 1792)           7168      ['top_conv[0][0]']
#  )
#
#  top_activation (Activation  (None, 8, 8, 1792)           0         ['top_bn[0][0]']
#  )
#
#  global_average_pooling2d_3  (None, 1792)                 0         ['top_activation[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_6 (Dense)             (None, 32)                   57376     ['global_average_pooling2d_3[0
#                                                                     ][0]']
#
#  dense_7 (Dense)             (None, 3)                    99        ['dense_6[0][0]']
#
# ==================================================================================================
# Total params: 17731298 (67.64 MB)
# Trainable params: 57475 (224.51 KB)
# Non-trainable params: 17673823 (67.42 MB)
# __________________________________________________________________________________________________

# %%
# annotate the layer to be quantized during training

def annotate_layer(layer_name):
  if "conv" in layer_name.name:
    return tfmot.quantization.keras.quantize_annotate_layer(layer_name)
  return layer_name


effnet_b4_quantize = tf.keras.models.clone_model(
    model, clone_function=annotate_layer
)


effnet_b4_quantize.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  rescaling_2 (Rescaling)     (None, 256, 256, 3)          0         ['input_2[0][0]']
#
#  normalization_1 (Normaliza  (None, 256, 256, 3)          7         ['rescaling_2[6][0]']
#  tion)
#
#  rescaling_3 (Rescaling)     (None, 256, 256, 3)          0         ['normalization_1[6][0]']
#
#  quantize_annotate_505 (Qua  (None, 257, 257, 3)          0         ['rescaling_3[6][0]']
#  ntizeAnnotate)
#
#  quantize_annotate_506 (Qua  (None, 128, 128, 48)         1296      ['quantize_annotate_505[0][0]'
#  ntizeAnnotate)                                                     ]
#
#  stem_bn (BatchNormalizatio  (None, 128, 128, 48)         192       ['quantize_annotate_506[0][0]'
#  n)                                                                 ]
#
#  stem_activation (Activatio  (None, 128, 128, 48)         0         ['stem_bn[6][0]']
#  n)
#
#  quantize_annotate_507 (Qua  (None, 128, 128, 48)         432       ['stem_activation[6][0]']
#  ntizeAnnotate)
#
#  block1a_bn (BatchNormaliza  (None, 128, 128, 48)         192       ['quantize_annotate_507[0][0]'
#  tion)                                                              ]
#
#  block1a_activation (Activa  (None, 128, 128, 48)         0         ['block1a_bn[6][0]']
#  tion)
#
#  block1a_se_squeeze (Global  (None, 48)                   0         ['block1a_activation[6][0]']
#  AveragePooling2D)
#
#  block1a_se_reshape (Reshap  (None, 1, 1, 48)             0         ['block1a_se_squeeze[6][0]']
#  e)
#
#  block1a_se_reduce (Conv2D)  (None, 1, 1, 12)             588       ['block1a_se_reshape[6][0]']
#
#  block1a_se_expand (Conv2D)  (None, 1, 1, 48)             624       ['block1a_se_reduce[6][0]']
#
#  block1a_se_excite (Multipl  (None, 128, 128, 48)         0         ['block1a_activation[6][0]',
#  y)                                                                  'block1a_se_expand[6][0]']
#
#  quantize_annotate_508 (Qua  (None, 128, 128, 24)         1152      ['block1a_se_excite[6][0]']
#  ntizeAnnotate)
#
#  block1a_project_bn (BatchN  (None, 128, 128, 24)         96        ['quantize_annotate_508[0][0]'
#  ormalization)                                                      ]
#
#  quantize_annotate_509 (Qua  (None, 128, 128, 24)         216       ['block1a_project_bn[6][0]']
#  ntizeAnnotate)
#
#  block1b_bn (BatchNormaliza  (None, 128, 128, 24)         96        ['quantize_annotate_509[0][0]'
#  tion)                                                              ]
#
#  block1b_activation (Activa  (None, 128, 128, 24)         0         ['block1b_bn[6][0]']
#  tion)
#
#  block1b_se_squeeze (Global  (None, 24)                   0         ['block1b_activation[6][0]']
#  AveragePooling2D)
#
#  block1b_se_reshape (Reshap  (None, 1, 1, 24)             0         ['block1b_se_squeeze[6][0]']
#  e)
#
#  block1b_se_reduce (Conv2D)  (None, 1, 1, 6)              150       ['block1b_se_reshape[6][0]']
#
#  block1b_se_expand (Conv2D)  (None, 1, 1, 24)             168       ['block1b_se_reduce[6][0]']
#
#  block1b_se_excite (Multipl  (None, 128, 128, 24)         0         ['block1b_activation[6][0]',
#  y)                                                                  'block1b_se_expand[6][0]']
#
#  quantize_annotate_510 (Qua  (None, 128, 128, 24)         576       ['block1b_se_excite[6][0]']
#  ntizeAnnotate)
#
#  block1b_project_bn (BatchN  (None, 128, 128, 24)         96        ['quantize_annotate_510[0][0]'
#  ormalization)                                                      ]
#
#  block1b_drop (Dropout)      (None, 128, 128, 24)         0         ['block1b_project_bn[6][0]']
#
#  block1b_add (Add)           (None, 128, 128, 24)         0         ['block1b_drop[6][0]',
#                                                                      'block1a_project_bn[6][0]']
#
#  quantize_annotate_511 (Qua  (None, 128, 128, 144)        3456      ['block1b_add[6][0]']
#  ntizeAnnotate)
#
#  block2a_expand_bn (BatchNo  (None, 128, 128, 144)        576       ['quantize_annotate_511[0][0]'
#  rmalization)                                                       ]
#
#  block2a_expand_activation   (None, 128, 128, 144)        0         ['block2a_expand_bn[6][0]']
#  (Activation)
#
#  quantize_annotate_512 (Qua  (None, 129, 129, 144)        0         ['block2a_expand_activation[6]
#  ntizeAnnotate)                                                     [0]']
#
#  quantize_annotate_513 (Qua  (None, 64, 64, 144)          1296      ['quantize_annotate_512[0][0]'
#  ntizeAnnotate)                                                     ]
#
#  block2a_bn (BatchNormaliza  (None, 64, 64, 144)          576       ['quantize_annotate_513[0][0]'
#  tion)                                                              ]
#
#  block2a_activation (Activa  (None, 64, 64, 144)          0         ['block2a_bn[6][0]']
#  tion)
#
#  block2a_se_squeeze (Global  (None, 144)                  0         ['block2a_activation[6][0]']
#  AveragePooling2D)
#
#  block2a_se_reshape (Reshap  (None, 1, 1, 144)            0         ['block2a_se_squeeze[6][0]']
#  e)
#
#  block2a_se_reduce (Conv2D)  (None, 1, 1, 6)              870       ['block2a_se_reshape[6][0]']
#
#  block2a_se_expand (Conv2D)  (None, 1, 1, 144)            1008      ['block2a_se_reduce[6][0]']
#
#  block2a_se_excite (Multipl  (None, 64, 64, 144)          0         ['block2a_activation[6][0]',
#  y)                                                                  'block2a_se_expand[6][0]']
#
#  quantize_annotate_514 (Qua  (None, 64, 64, 32)           4608      ['block2a_se_excite[6][0]']
#  ntizeAnnotate)
#
#  block2a_project_bn (BatchN  (None, 64, 64, 32)           128       ['quantize_annotate_514[0][0]'
#  ormalization)                                                      ]
#
#  quantize_annotate_515 (Qua  (None, 64, 64, 192)          6144      ['block2a_project_bn[6][0]']
#  ntizeAnnotate)
#
#  block2b_expand_bn (BatchNo  (None, 64, 64, 192)          768       ['quantize_annotate_515[0][0]'
#  rmalization)                                                       ]
#
#  block2b_expand_activation   (None, 64, 64, 192)          0         ['block2b_expand_bn[6][0]']
#  (Activation)
#
#  quantize_annotate_516 (Qua  (None, 64, 64, 192)          1728      ['block2b_expand_activation[6]
#  ntizeAnnotate)                                                     [0]']
#
#  block2b_bn (BatchNormaliza  (None, 64, 64, 192)          768       ['quantize_annotate_516[0][0]'
#  tion)                                                              ]
#
#  block2b_activation (Activa  (None, 64, 64, 192)          0         ['block2b_bn[6][0]']
#  tion)
#
#  block2b_se_squeeze (Global  (None, 192)                  0         ['block2b_activation[6][0]']
#  AveragePooling2D)
#
#  block2b_se_reshape (Reshap  (None, 1, 1, 192)            0         ['block2b_se_squeeze[6][0]']
#  e)
#
#  block2b_se_reduce (Conv2D)  (None, 1, 1, 8)              1544      ['block2b_se_reshape[6][0]']
#
#  block2b_se_expand (Conv2D)  (None, 1, 1, 192)            1728      ['block2b_se_reduce[6][0]']
#
#  block2b_se_excite (Multipl  (None, 64, 64, 192)          0         ['block2b_activation[6][0]',
#  y)                                                                  'block2b_se_expand[6][0]']
#
#  quantize_annotate_517 (Qua  (None, 64, 64, 32)           6144      ['block2b_se_excite[6][0]']
#  ntizeAnnotate)
#
#  block2b_project_bn (BatchN  (None, 64, 64, 32)           128       ['quantize_annotate_517[0][0]'
#  ormalization)                                                      ]
#
#  block2b_drop (Dropout)      (None, 64, 64, 32)           0         ['block2b_project_bn[6][0]']
#
#  block2b_add (Add)           (None, 64, 64, 32)           0         ['block2b_drop[6][0]',
#                                                                      'block2a_project_bn[6][0]']
#
#  quantize_annotate_518 (Qua  (None, 64, 64, 192)          6144      ['block2b_add[6][0]']
#  ntizeAnnotate)
#
#  block2c_expand_bn (BatchNo  (None, 64, 64, 192)          768       ['quantize_annotate_518[0][0]'
#  rmalization)                                                       ]
#
#  block2c_expand_activation   (None, 64, 64, 192)          0         ['block2c_expand_bn[6][0]']
#  (Activation)
#
#  quantize_annotate_519 (Qua  (None, 64, 64, 192)          1728      ['block2c_expand_activation[6]
#  ntizeAnnotate)                                                     [0]']
#
#  block2c_bn (BatchNormaliza  (None, 64, 64, 192)          768       ['quantize_annotate_519[0][0]'
#  tion)                                                              ]
#
#  block2c_activation (Activa  (None, 64, 64, 192)          0         ['block2c_bn[6][0]']
#  tion)
#
#  block2c_se_squeeze (Global  (None, 192)                  0         ['block2c_activation[6][0]']
#  AveragePooling2D)
#
#  block2c_se_reshape (Reshap  (None, 1, 1, 192)            0         ['block2c_se_squeeze[6][0]']
#  e)
#
#  block2c_se_reduce (Conv2D)  (None, 1, 1, 8)              1544      ['block2c_se_reshape[6][0]']
#
#  block2c_se_expand (Conv2D)  (None, 1, 1, 192)            1728      ['block2c_se_reduce[6][0]']
#
#  block2c_se_excite (Multipl  (None, 64, 64, 192)          0         ['block2c_activation[6][0]',
#  y)                                                                  'block2c_se_expand[6][0]']
#
#  quantize_annotate_520 (Qua  (None, 64, 64, 32)           6144      ['block2c_se_excite[6][0]']
#  ntizeAnnotate)
#
#  block2c_project_bn (BatchN  (None, 64, 64, 32)           128       ['quantize_annotate_520[0][0]'
#  ormalization)                                                      ]
#
#  block2c_drop (Dropout)      (None, 64, 64, 32)           0         ['block2c_project_bn[6][0]']
#
#  block2c_add (Add)           (None, 64, 64, 32)           0         ['block2c_drop[6][0]',
#                                                                      'block2b_add[6][0]']
#
#  quantize_annotate_521 (Qua  (None, 64, 64, 192)          6144      ['block2c_add[6][0]']
#  ntizeAnnotate)
#
#  block2d_expand_bn (BatchNo  (None, 64, 64, 192)          768       ['quantize_annotate_521[0][0]'
#  rmalization)                                                       ]
#
#  block2d_expand_activation   (None, 64, 64, 192)          0         ['block2d_expand_bn[6][0]']
#  (Activation)
#
#  quantize_annotate_522 (Qua  (None, 64, 64, 192)          1728      ['block2d_expand_activation[6]
#  ntizeAnnotate)                                                     [0]']
#
#  block2d_bn (BatchNormaliza  (None, 64, 64, 192)          768       ['quantize_annotate_522[0][0]'
#  tion)                                                              ]
#
#  block2d_activation (Activa  (None, 64, 64, 192)          0         ['block2d_bn[6][0]']
#  tion)
#
#  block2d_se_squeeze (Global  (None, 192)                  0         ['block2d_activation[6][0]']
#  AveragePooling2D)
#
#  block2d_se_reshape (Reshap  (None, 1, 1, 192)            0         ['block2d_se_squeeze[6][0]']
#  e)
#
#  block2d_se_reduce (Conv2D)  (None, 1, 1, 8)              1544      ['block2d_se_reshape[6][0]']
#
#  block2d_se_expand (Conv2D)  (None, 1, 1, 192)            1728      ['block2d_se_reduce[6][0]']
#
#  block2d_se_excite (Multipl  (None, 64, 64, 192)          0         ['block2d_activation[6][0]',
#  y)                                                                  'block2d_se_expand[6][0]']
#
#  quantize_annotate_523 (Qua  (None, 64, 64, 32)           6144      ['block2d_se_excite[6][0]']
#  ntizeAnnotate)
#
#  block2d_project_bn (BatchN  (None, 64, 64, 32)           128       ['quantize_annotate_523[0][0]'
#  ormalization)                                                      ]
#
#  block2d_drop (Dropout)      (None, 64, 64, 32)           0         ['block2d_project_bn[6][0]']
#
#  block2d_add (Add)           (None, 64, 64, 32)           0         ['block2d_drop[6][0]',
#                                                                      'block2c_add[6][0]']
#
#  quantize_annotate_524 (Qua  (None, 64, 64, 192)          6144      ['block2d_add[6][0]']
#  ntizeAnnotate)
#
#  block3a_expand_bn (BatchNo  (None, 64, 64, 192)          768       ['quantize_annotate_524[0][0]'
#  rmalization)                                                       ]
#
#  block3a_expand_activation   (None, 64, 64, 192)          0         ['block3a_expand_bn[6][0]']
#  (Activation)
#
#  quantize_annotate_525 (Qua  (None, 67, 67, 192)          0         ['block3a_expand_activation[6]
#  ntizeAnnotate)                                                     [0]']
#
#  quantize_annotate_526 (Qua  (None, 32, 32, 192)          4800      ['quantize_annotate_525[0][0]'
#  ntizeAnnotate)                                                     ]
#
#  block3a_bn (BatchNormaliza  (None, 32, 32, 192)          768       ['quantize_annotate_526[0][0]'
#  tion)                                                              ]
#
#  block3a_activation (Activa  (None, 32, 32, 192)          0         ['block3a_bn[6][0]']
#  tion)
#
#  block3a_se_squeeze (Global  (None, 192)                  0         ['block3a_activation[6][0]']
#  AveragePooling2D)
#
#  block3a_se_reshape (Reshap  (None, 1, 1, 192)            0         ['block3a_se_squeeze[6][0]']
#  e)
#
#  block3a_se_reduce (Conv2D)  (None, 1, 1, 8)              1544      ['block3a_se_reshape[6][0]']
#
#  block3a_se_expand (Conv2D)  (None, 1, 1, 192)            1728      ['block3a_se_reduce[6][0]']
#
#  block3a_se_excite (Multipl  (None, 32, 32, 192)          0         ['block3a_activation[6][0]',
#  y)                                                                  'block3a_se_expand[6][0]']
#
#  quantize_annotate_527 (Qua  (None, 32, 32, 56)           10752     ['block3a_se_excite[6][0]']
#  ntizeAnnotate)
#
#  block3a_project_bn (BatchN  (None, 32, 32, 56)           224       ['quantize_annotate_527[0][0]'
#  ormalization)                                                      ]
#
#  quantize_annotate_528 (Qua  (None, 32, 32, 336)          18816     ['block3a_project_bn[6][0]']
#  ntizeAnnotate)
#
#  block3b_expand_bn (BatchNo  (None, 32, 32, 336)          1344      ['quantize_annotate_528[0][0]'
#  rmalization)                                                       ]
#
#  block3b_expand_activation   (None, 32, 32, 336)          0         ['block3b_expand_bn[6][0]']
#  (Activation)
#
#  quantize_annotate_529 (Qua  (None, 32, 32, 336)          8400      ['block3b_expand_activation[6]
#  ntizeAnnotate)                                                     [0]']
#
#  block3b_bn (BatchNormaliza  (None, 32, 32, 336)          1344      ['quantize_annotate_529[0][0]'
#  tion)                                                              ]
#
#  block3b_activation (Activa  (None, 32, 32, 336)          0         ['block3b_bn[6][0]']
#  tion)
#
#  block3b_se_squeeze (Global  (None, 336)                  0         ['block3b_activation[6][0]']
#  AveragePooling2D)
#
#  block3b_se_reshape (Reshap  (None, 1, 1, 336)            0         ['block3b_se_squeeze[6][0]']
#  e)
#
#  block3b_se_reduce (Conv2D)  (None, 1, 1, 14)             4718      ['block3b_se_reshape[6][0]']
#
#  block3b_se_expand (Conv2D)  (None, 1, 1, 336)            5040      ['block3b_se_reduce[6][0]']
#
#  block3b_se_excite (Multipl  (None, 32, 32, 336)          0         ['block3b_activation[6][0]',
#  y)                                                                  'block3b_se_expand[6][0]']
#
#  quantize_annotate_530 (Qua  (None, 32, 32, 56)           18816     ['block3b_se_excite[6][0]']
#  ntizeAnnotate)
#
#  block3b_project_bn (BatchN  (None, 32, 32, 56)           224       ['quantize_annotate_530[0][0]'
#  ormalization)                                                      ]
#
#  block3b_drop (Dropout)      (None, 32, 32, 56)           0         ['block3b_project_bn[6][0]']
#
#  block3b_add (Add)           (None, 32, 32, 56)           0         ['block3b_drop[6][0]',
#                                                                      'block3a_project_bn[6][0]']
#
#  quantize_annotate_531 (Qua  (None, 32, 32, 336)          18816     ['block3b_add[6][0]']
#  ntizeAnnotate)
#
#  block3c_expand_bn (BatchNo  (None, 32, 32, 336)          1344      ['quantize_annotate_531[0][0]'
#  rmalization)                                                       ]
#
#  block3c_expand_activation   (None, 32, 32, 336)          0         ['block3c_expand_bn[6][0]']
#  (Activation)
#
#  quantize_annotate_532 (Qua  (None, 32, 32, 336)          8400      ['block3c_expand_activation[6]
#  ntizeAnnotate)                                                     [0]']
#
#  block3c_bn (BatchNormaliza  (None, 32, 32, 336)          1344      ['quantize_annotate_532[0][0]'
#  tion)                                                              ]
#
#  block3c_activation (Activa  (None, 32, 32, 336)          0         ['block3c_bn[6][0]']
#  tion)
#
#  block3c_se_squeeze (Global  (None, 336)                  0         ['block3c_activation[6][0]']
#  AveragePooling2D)
#
#  block3c_se_reshape (Reshap  (None, 1, 1, 336)            0         ['block3c_se_squeeze[6][0]']
#  e)
#
#  block3c_se_reduce (Conv2D)  (None, 1, 1, 14)             4718      ['block3c_se_reshape[6][0]']
#
#  block3c_se_expand (Conv2D)  (None, 1, 1, 336)            5040      ['block3c_se_reduce[6][0]']
#
#  block3c_se_excite (Multipl  (None, 32, 32, 336)          0         ['block3c_activation[6][0]',
#  y)                                                                  'block3c_se_expand[6][0]']
#
#  quantize_annotate_533 (Qua  (None, 32, 32, 56)           18816     ['block3c_se_excite[6][0]']
#  ntizeAnnotate)
#
#  block3c_project_bn (BatchN  (None, 32, 32, 56)           224       ['quantize_annotate_533[0][0]'
#  ormalization)                                                      ]
#
#  block3c_drop (Dropout)      (None, 32, 32, 56)           0         ['block3c_project_bn[6][0]']
#
#  block3c_add (Add)           (None, 32, 32, 56)           0         ['block3c_drop[6][0]',
#                                                                      'block3b_add[6][0]']
#
#  quantize_annotate_534 (Qua  (None, 32, 32, 336)          18816     ['block3c_add[6][0]']
#  ntizeAnnotate)
#
#  block3d_expand_bn (BatchNo  (None, 32, 32, 336)          1344      ['quantize_annotate_534[0][0]'
#  rmalization)                                                       ]
#
#  block3d_expand_activation   (None, 32, 32, 336)          0         ['block3d_expand_bn[6][0]']
#  (Activation)
#
#  quantize_annotate_535 (Qua  (None, 32, 32, 336)          8400      ['block3d_expand_activation[6]
#  ntizeAnnotate)                                                     [0]']
#
#  block3d_bn (BatchNormaliza  (None, 32, 32, 336)          1344      ['quantize_annotate_535[0][0]'
#  tion)                                                              ]
#
#  block3d_activation (Activa  (None, 32, 32, 336)          0         ['block3d_bn[6][0]']
#  tion)
#
#  block3d_se_squeeze (Global  (None, 336)                  0         ['block3d_activation[6][0]']
#  AveragePooling2D)
#
#  block3d_se_reshape (Reshap  (None, 1, 1, 336)            0         ['block3d_se_squeeze[6][0]']
#  e)
#
#  block3d_se_reduce (Conv2D)  (None, 1, 1, 14)             4718      ['block3d_se_reshape[6][0]']
#
#  block3d_se_expand (Conv2D)  (None, 1, 1, 336)            5040      ['block3d_se_reduce[6][0]']
#
#  block3d_se_excite (Multipl  (None, 32, 32, 336)          0         ['block3d_activation[6][0]',
#  y)                                                                  'block3d_se_expand[6][0]']
#
#  quantize_annotate_536 (Qua  (None, 32, 32, 56)           18816     ['block3d_se_excite[6][0]']
#  ntizeAnnotate)
#
#  block3d_project_bn (BatchN  (None, 32, 32, 56)           224       ['quantize_annotate_536[0][0]'
#  ormalization)                                                      ]
#
#  block3d_drop (Dropout)      (None, 32, 32, 56)           0         ['block3d_project_bn[6][0]']
#
#  block3d_add (Add)           (None, 32, 32, 56)           0         ['block3d_drop[6][0]',
#                                                                      'block3c_add[6][0]']
#
#  quantize_annotate_537 (Qua  (None, 32, 32, 336)          18816     ['block3d_add[6][0]']
#  ntizeAnnotate)
#
#  block4a_expand_bn (BatchNo  (None, 32, 32, 336)          1344      ['quantize_annotate_537[0][0]'
#  rmalization)                                                       ]
#
#  block4a_expand_activation   (None, 32, 32, 336)          0         ['block4a_expand_bn[6][0]']
#  (Activation)
#
#  quantize_annotate_538 (Qua  (None, 33, 33, 336)          0         ['block4a_expand_activation[6]
#  ntizeAnnotate)                                                     [0]']
#
#  quantize_annotate_539 (Qua  (None, 16, 16, 336)          3024      ['quantize_annotate_538[0][0]'
#  ntizeAnnotate)                                                     ]
#
#  block4a_bn (BatchNormaliza  (None, 16, 16, 336)          1344      ['quantize_annotate_539[0][0]'
#  tion)                                                              ]
#
#  block4a_activation (Activa  (None, 16, 16, 336)          0         ['block4a_bn[6][0]']
#  tion)
#
#  block4a_se_squeeze (Global  (None, 336)                  0         ['block4a_activation[6][0]']
#  AveragePooling2D)
#
#  block4a_se_reshape (Reshap  (None, 1, 1, 336)            0         ['block4a_se_squeeze[6][0]']
#  e)
#
#  block4a_se_reduce (Conv2D)  (None, 1, 1, 14)             4718      ['block4a_se_reshape[6][0]']
#
#  block4a_se_expand (Conv2D)  (None, 1, 1, 336)            5040      ['block4a_se_reduce[6][0]']
#
#  block4a_se_excite (Multipl  (None, 16, 16, 336)          0         ['block4a_activation[6][0]',
#  y)                                                                  'block4a_se_expand[6][0]']
#
#  quantize_annotate_540 (Qua  (None, 16, 16, 112)          37632     ['block4a_se_excite[6][0]']
#  ntizeAnnotate)
#
#  block4a_project_bn (BatchN  (None, 16, 16, 112)          448       ['quantize_annotate_540[0][0]'
#  ormalization)                                                      ]
#
#  quantize_annotate_541 (Qua  (None, 16, 16, 672)          75264     ['block4a_project_bn[6][0]']
#  ntizeAnnotate)
#
#  block4b_expand_bn (BatchNo  (None, 16, 16, 672)          2688      ['quantize_annotate_541[0][0]'
#  rmalization)                                                       ]
#
#  block4b_expand_activation   (None, 16, 16, 672)          0         ['block4b_expand_bn[6][0]']
#  (Activation)
#
#  quantize_annotate_542 (Qua  (None, 16, 16, 672)          6048      ['block4b_expand_activation[6]
#  ntizeAnnotate)                                                     [0]']
#
#  block4b_bn (BatchNormaliza  (None, 16, 16, 672)          2688      ['quantize_annotate_542[0][0]'
#  tion)                                                              ]
#
#  block4b_activation (Activa  (None, 16, 16, 672)          0         ['block4b_bn[6][0]']
#  tion)
#
#  block4b_se_squeeze (Global  (None, 672)                  0         ['block4b_activation[6][0]']
#  AveragePooling2D)
#
#  block4b_se_reshape (Reshap  (None, 1, 1, 672)            0         ['block4b_se_squeeze[6][0]']
#  e)
#
#  block4b_se_reduce (Conv2D)  (None, 1, 1, 28)             18844     ['block4b_se_reshape[6][0]']
#
#  block4b_se_expand (Conv2D)  (None, 1, 1, 672)            19488     ['block4b_se_reduce[6][0]']
# ...
#  e)
#
#  block6g_se_reduce (Conv2D)  (None, 1, 1, 68)             111044    ['block6g_se_reshape[6][0]']
#
#  block6g_se_expand (Conv2D)  (None, 1, 1, 1632)           112608    ['block6g_se_reduce[6][0]']
#
#  block6g_se_excite (Multipl  (None, 8, 8, 1632)           0         ['block6g_activation[6][0]',
#  y)                                                                  'block6g_se_expand[6][0]']
#
#  quantize_annotate_595 (Qua  (None, 8, 8, 272)            443904    ['block6g_se_excite[6][0]']
#  ntizeAnnotate)
#
#  block6g_project_bn (BatchN  (None, 8, 8, 272)            1088      ['quantize_annotate_595[0][0]'
#  ormalization)                                                      ]
#
#  block6g_drop (Dropout)      (None, 8, 8, 272)            0         ['block6g_project_bn[6][0]']
#
#  block6g_add (Add)           (None, 8, 8, 272)            0         ['block6g_drop[6][0]',
#                                                                      'block6f_add[6][0]']
#
#  quantize_annotate_596 (Qua  (None, 8, 8, 1632)           443904    ['block6g_add[6][0]']
#  ntizeAnnotate)
#
#  block6h_expand_bn (BatchNo  (None, 8, 8, 1632)           6528      ['quantize_annotate_596[0][0]'
#  rmalization)                                                       ]
#
#  block6h_expand_activation   (None, 8, 8, 1632)           0         ['block6h_expand_bn[6][0]']
#  (Activation)
#
#  quantize_annotate_597 (Qua  (None, 8, 8, 1632)           40800     ['block6h_expand_activation[6]
#  ntizeAnnotate)                                                     [0]']
#
#  block6h_bn (BatchNormaliza  (None, 8, 8, 1632)           6528      ['quantize_annotate_597[0][0]'
#  tion)                                                              ]
#
#  block6h_activation (Activa  (None, 8, 8, 1632)           0         ['block6h_bn[6][0]']
#  tion)
#
#  block6h_se_squeeze (Global  (None, 1632)                 0         ['block6h_activation[6][0]']
#  AveragePooling2D)
#
#  block6h_se_reshape (Reshap  (None, 1, 1, 1632)           0         ['block6h_se_squeeze[6][0]']
#  e)
#
#  block6h_se_reduce (Conv2D)  (None, 1, 1, 68)             111044    ['block6h_se_reshape[6][0]']
#
#  block6h_se_expand (Conv2D)  (None, 1, 1, 1632)           112608    ['block6h_se_reduce[6][0]']
#
#  block6h_se_excite (Multipl  (None, 8, 8, 1632)           0         ['block6h_activation[6][0]',
#  y)                                                                  'block6h_se_expand[6][0]']
#
#  quantize_annotate_598 (Qua  (None, 8, 8, 272)            443904    ['block6h_se_excite[6][0]']
#  ntizeAnnotate)
#
#  block6h_project_bn (BatchN  (None, 8, 8, 272)            1088      ['quantize_annotate_598[0][0]'
#  ormalization)                                                      ]
#
#  block6h_drop (Dropout)      (None, 8, 8, 272)            0         ['block6h_project_bn[6][0]']
#
#  block6h_add (Add)           (None, 8, 8, 272)            0         ['block6h_drop[6][0]',
#                                                                      'block6g_add[6][0]']
#
#  quantize_annotate_599 (Qua  (None, 8, 8, 1632)           443904    ['block6h_add[6][0]']
#  ntizeAnnotate)
#
#  block7a_expand_bn (BatchNo  (None, 8, 8, 1632)           6528      ['quantize_annotate_599[0][0]'
#  rmalization)                                                       ]
#
#  block7a_expand_activation   (None, 8, 8, 1632)           0         ['block7a_expand_bn[6][0]']
#  (Activation)
#
#  quantize_annotate_600 (Qua  (None, 8, 8, 1632)           14688     ['block7a_expand_activation[6]
#  ntizeAnnotate)                                                     [0]']
#
#  block7a_bn (BatchNormaliza  (None, 8, 8, 1632)           6528      ['quantize_annotate_600[0][0]'
#  tion)                                                              ]
#
#  block7a_activation (Activa  (None, 8, 8, 1632)           0         ['block7a_bn[6][0]']
#  tion)
#
#  block7a_se_squeeze (Global  (None, 1632)                 0         ['block7a_activation[6][0]']
#  AveragePooling2D)
#
#  block7a_se_reshape (Reshap  (None, 1, 1, 1632)           0         ['block7a_se_squeeze[6][0]']
#  e)
#
#  block7a_se_reduce (Conv2D)  (None, 1, 1, 68)             111044    ['block7a_se_reshape[6][0]']
#
#  block7a_se_expand (Conv2D)  (None, 1, 1, 1632)           112608    ['block7a_se_reduce[6][0]']
#
#  block7a_se_excite (Multipl  (None, 8, 8, 1632)           0         ['block7a_activation[6][0]',
#  y)                                                                  'block7a_se_expand[6][0]']
#
#  quantize_annotate_601 (Qua  (None, 8, 8, 448)            731136    ['block7a_se_excite[6][0]']
#  ntizeAnnotate)
#
#  block7a_project_bn (BatchN  (None, 8, 8, 448)            1792      ['quantize_annotate_601[0][0]'
#  ormalization)                                                      ]
#
#  quantize_annotate_602 (Qua  (None, 8, 8, 2688)           1204224   ['block7a_project_bn[6][0]']
#  ntizeAnnotate)
#
#  block7b_expand_bn (BatchNo  (None, 8, 8, 2688)           10752     ['quantize_annotate_602[0][0]'
#  rmalization)                                                       ]
#
#  block7b_expand_activation   (None, 8, 8, 2688)           0         ['block7b_expand_bn[6][0]']
#  (Activation)
#
#  quantize_annotate_603 (Qua  (None, 8, 8, 2688)           24192     ['block7b_expand_activation[6]
#  ntizeAnnotate)                                                     [0]']
#
#  block7b_bn (BatchNormaliza  (None, 8, 8, 2688)           10752     ['quantize_annotate_603[0][0]'
#  tion)                                                              ]
#
#  block7b_activation (Activa  (None, 8, 8, 2688)           0         ['block7b_bn[6][0]']
#  tion)
#
#  block7b_se_squeeze (Global  (None, 2688)                 0         ['block7b_activation[6][0]']
#  AveragePooling2D)
#
#  block7b_se_reshape (Reshap  (None, 1, 1, 2688)           0         ['block7b_se_squeeze[6][0]']
#  e)
#
#  block7b_se_reduce (Conv2D)  (None, 1, 1, 112)            301168    ['block7b_se_reshape[6][0]']
#
#  block7b_se_expand (Conv2D)  (None, 1, 1, 2688)           303744    ['block7b_se_reduce[6][0]']
#
#  block7b_se_excite (Multipl  (None, 8, 8, 2688)           0         ['block7b_activation[6][0]',
#  y)                                                                  'block7b_se_expand[6][0]']
#
#  quantize_annotate_604 (Qua  (None, 8, 8, 448)            1204224   ['block7b_se_excite[6][0]']
#  ntizeAnnotate)
#
#  block7b_project_bn (BatchN  (None, 8, 8, 448)            1792      ['quantize_annotate_604[0][0]'
#  ormalization)                                                      ]
#
#  block7b_drop (Dropout)      (None, 8, 8, 448)            0         ['block7b_project_bn[6][0]']
#
#  block7b_add (Add)           (None, 8, 8, 448)            0         ['block7b_drop[6][0]',
#                                                                      'block7a_project_bn[6][0]']
#
#  quantize_annotate_605 (Qua  (None, 8, 8, 1792)           802816    ['block7b_add[6][0]']
#  ntizeAnnotate)
#
#  top_bn (BatchNormalization  (None, 8, 8, 1792)           7168      ['quantize_annotate_605[0][0]'
#  )                                                                  ]
#
#  top_activation (Activation  (None, 8, 8, 1792)           0         ['top_bn[6][0]']
#  )
#
#  global_average_pooling2d_3  (None, 1792)                 0         ['top_activation[6][0]']
#   (GlobalAveragePooling2D)
#
#  dense_6 (Dense)             (None, 32)                   57376     ['global_average_pooling2d_3[2
#                                                                     ][0]']
#
#  dense_7 (Dense)             (None, 3)                    99        ['dense_6[2][0]']
#
# ==================================================================================================
# Total params: 17731298 (67.64 MB)
# Trainable params: 57475 (224.51 KB)
# Non-trainable params: 17673823 (67.42 MB)
# __________________________________________________________________________________________________

# %%
effnet_b4_quantize.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=CONFIG['LEARNING_RATE']),
    loss='categorical_crossentropy',
    metrics=['accuracy'],
)


effnet_b4_quantize.fit(train_dataset.take(5), epochs=1, verbose=1)
# Out:
# 5/5 [==============================] - 69s 9s/step - loss: 1.1025 - accuracy: 0.4688

# %% [markdown]
# ### Dynamic Quantization

# %%
# !pip install -q -U onnx
# !pip install -q onnxruntime

# %%
import onnx
import onnxruntime as ort
from onnxruntime.quantization import quantize_dynamic, QuantType

# %%
# Dynamic Quantization of onnx model
onnx_model_path = "/content/gdrive/MyDrive/dl_models/human-emotion-detection-tf-vit-model.onnx"
onnx_quantized_model_path = "human-emotion-detection-tf-vit-model-quant.onnx"

quantized_model = quantize_dynamic(onnx_model_path, onnx_quantized_model_path, weight_type=QuantType.QUInt8)
# Out:
# WARNING:root:Please consider to run pre-processing before quantization. Refer to example: https://github.com/microsoft/onnxruntime-inference-examples/blob/main/quantization/image_classification/cpu/ReadMe.md

# %%
# onnx quantized inference
img_array = tf.expand_dims(img, axis=0)
output_names = ['output_1']
provider = ["CPUExecutionProvider"]
m = ort.InferenceSession("/content/gdrive/MyDrive/dl_models/human-emotion-detection-tf-vit-model.onnx", providers=provider)
pred = m.run(output_names, {m.get_inputs()[0].name: np.array(img_array)})
pred
# Out:
# [array([[0.9939393 , 0.00270534, 0.00335543]], dtype=float32)]

# %%
def acc(model):
  start_time = time.time()
  acc = 0
  total, correct_pred = 0, 0
  output_names = ['output_1']

  for x, y in validation_dataset.take(1):
    for img, lbl in zip(x, y):
      pred = m.run(output_names, {m.get_inputs()[0].name: np.array(np.expand_dims(img, axis=0))})

      if (tf.argmax(pred[0][0]).numpy() == tf.argmax(lbl).numpy()):
        correct_pred += 1

      total += 1
  acc = (correct_pred/total) * 100

  return acc, (time.time() - start_time)

# %%
provider = ["CPUExecutionProvider"]
m = ort.InferenceSession("/content/gdrive/MyDrive/dl_models/human-emotion-detection-tf-vit-model.onnx", providers=provider)
m_quant = ort.InferenceSession("human-emotion-detection-tf-vit-model-quant.onnx", providers=provider)


print(f"Accuracy before quantization: {acc(m)}")
print(f"Accuracy after quantization: {acc(m_quant)}")
# Out:
# Accuracy before quantization: (87.5, 25.1528480052948)
# Accuracy after quantization: (87.5, 41.02073264122009)
